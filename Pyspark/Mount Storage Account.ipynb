# %%
dbutils.fs.mounts()

# %%
dbutils.fs.unmount("/mnt/rainbowcontainer")

# %%
dbutils.fs.mounts()

# %%
client_id = dbutils.secrets.get(scope="sc-rainbow-vault-batch02", key="clinet-id")
client_secret = dbutils.secrets.get(scope="sc-rainbow-vault-batch02", key="client-secret")
tenant_id = dbutils.secrets.get(scope="sc-rainbow-vault-batch02", key="tenent-id")

container_name = "databricks-container"
storage_account_name = "rainbowstorageadls"
mount_path = "/mnt/rainbowcontainer"

# %%
print(client_id)

# %%
configs = {
    "fs.azure.account.auth.type": "OAuth",
    "fs.azure.account.oauth.provider.type": "org.apache.hadoop.fs.azurebfs.oauth2.ClientCredsTokenProvider",
    "fs.azure.account.oauth2.client.id": client_id,
    "fs.azure.account.oauth2.client.secret": client_secret,
    "fs.azure.account.oauth2.client.endpoint": f"https://login.microsoftonline.com/{tenant_id}/oauth2/token"
}

# Optionally, you can add <directory-name> to the source URI of your mount point.
dbutils.fs.mount(
  source = f"abfss://{container_name}@{storage_account_name}.dfs.core.windows.net/",
  mount_point = mount_path,
  extra_configs = configs
)

# %%
dbutils.fs.mounts()

# %%
base_path = "/mnt/rainbowcontainer"
file_path = "raw-datasets/employee_salary_dataset.csv"

df = spark.read.format("csv").option("header", "true").option("inferSchema", True).load(f"{base_path}/{file_path}")

display(df)

# %%
df.write.format("parquet").mode("overwrite").save(f"{base_path}/employee_salary_dataset")
